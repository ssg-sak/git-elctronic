# %% [markdown]
# # 06 Modeling Readiness
#
# 현재 데이터로 가능한 규칙 기반 실험과, 향후 예측모델 학습 전 필요한 수집·품질 조건을 분리한다.
#
# - 현재는 `available_at_arrival` 라벨이 없어 완전한 예측모델 학습 불가.
# - MVP는 규칙 기반 점수와 데이터 신뢰도 중심으로 시작한다.
# - 반복 status, TMAP 이동시간, 요청/도착 로그가 필요하다.

# %%
import pandas as pd

readiness = pd.DataFrame([
    {'data': 'charger_master', 'grade': '사용 가능', 'reason': '기본정보/좌표/운영조건 존재'},
    {'data': 'charger_status_current', 'grade': '조건부 사용 가능', 'reason': '커버리지 2.34%, 관측분만'},
    {'data': 'status_timeseries', 'grade': '추가 수집 필요', 'reason': '반복 스냅샷 없음'},
    {'data': 'traffic', 'grade': '조건부 사용 가능', 'reason': 'mock 구조 검증'},
    {'data': 'target_available_at_arrival', 'grade': '현재 사용 불가', 'reason': '라벨 없음'},
])
readiness
